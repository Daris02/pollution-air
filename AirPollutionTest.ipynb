# %%
import os
import json
import requests
import pandas as pd
from dotenv import load_dotenv
from datetime import datetime

load_dotenv()

apiKey = os.getenv('API_KEY')

# %%
demographic = pd.read_csv('Demographic_Data.csv')
geographic = pd.read_csv('Geographic_Data.csv')

# %%
demographic
# Out:
#        Location  Population  Density (people/km²)  Urbanization (%)  \
# 0   Los Angeles    10039107                  3276                89
# 1         Paris     2140526                 21383                98
# 2         Tokyo    13929286                  6169               100
# 3  Antananarivo     1391433                  3097                69
# 4       Nairobi     4397073                  6000                61
# 5          Lima     9674755                  3220                81
#
#    Average Income (USD)  Education Level (% with Bachelor's or higher)
# 0                 60000                                             32
# 1                 45000                                             29
# 2                 55000                                             37
# 3                  1000                                             10
# 4                  1500                                             12
# 5                  4500                                             15

# %%
geographic
# Out:
#        Location  Altitude (m)  Proximity to Industry (km)
# 0   Los Angeles            89                         5.0
# 1         Paris            35                         3.0
# 2         Tokyo            40                         2.0
# 3  Antananarivo          1276                         0.5
# 4       Nairobi          1795                         1.0
# 5          Lima          1540                         1.5

# %%
location_data = pd.merge(geographic, demographic, on='Location')
location_data
# Out:
#        Location  Altitude (m)  Proximity to Industry (km)  Population  \
# 0   Los Angeles            89                         5.0    10039107
# 1         Paris            35                         3.0     2140526
# 2         Tokyo            40                         2.0    13929286
# 3  Antananarivo          1276                         0.5     1391433
# 4       Nairobi          1795                         1.0     4397073
# 5          Lima          1540                         1.5     9674755
#
#    Density (people/km²)  Urbanization (%)  Average Income (USD)  \
# 0                  3276                89                 60000
# 1                 21383                98                 45000
# 2                  6169               100                 55000
# 3                  3097                69                  1000
# 4                  6000                61                  1500
# 5                  3220                81                  4500
#
#    Education Level (% with Bachelor's or higher)
# 0                                             32
# 1                                             29
# 2                                             37
# 3                                             10
# 4                                             12
# 5                                             15

# %%
coord = pd.DataFrame(
  {
    'lat': [  34.052235, 48.866667,  34.886306, -18.777192,  0.170945,  -9.181352],
    'lon': [-118.243683,  2.333333, 134.379711,  46.854328, 37.903969, -75.002365],
    'Location': ['Los Angeles', 'Paris', 'Tokyo', 'Antananarivo', 'Nairobi', 'Lima']
  })
coord
# Out:
#          lat         lon      Location
# 0  34.052235 -118.243683   Los Angeles
# 1  48.866667    2.333333         Paris
# 2  34.886306  134.379711         Tokyo
# 3 -18.777192   46.854328  Antananarivo
# 4   0.170945   37.903969       Nairobi
# 5  -9.181352  -75.002365          Lima

# %%
location_data = pd.merge(location_data, coord, on='Location')
location_data
# Out:
#        Location  Altitude (m)  Proximity to Industry (km)  Population  \
# 0   Los Angeles            89                         5.0    10039107
# 1         Paris            35                         3.0     2140526
# 2         Tokyo            40                         2.0    13929286
# 3  Antananarivo          1276                         0.5     1391433
# 4       Nairobi          1795                         1.0     4397073
# 5          Lima          1540                         1.5     9674755
#
#    Density (people/km²)  Urbanization (%)  Average Income (USD)  \
# 0                  3276                89                 60000
# 1                 21383                98                 45000
# 2                  6169               100                 55000
# 3                  3097                69                  1000
# 4                  6000                61                  1500
# 5                  3220                81                  4500
#
#    Education Level (% with Bachelor's or higher)        lat         lon
# 0                                             32  34.052235 -118.243683
# 1                                             29  48.866667    2.333333
# 2                                             37  34.886306  134.379711
# 3                                             10 -18.777192   46.854328
# 4                                             12   0.170945   37.903969
# 5                                             15  -9.181352  -75.002365

# %%
def get_polution_aqi_data(row, apiKey):
    lat = row['lat']
    lon = row['lon']
    response = requests.get(f'http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={apiKey}')
    data = response.json()
    return data['list'][0]['main']['aqi']

def get_polution_components_data(row, apiKey):
    lat = row['lat']
    lon = row['lon']
    response = requests.get(f'http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={apiKey}')
    data = response.json()
    return data['list'][0]['components']

location_data['AQI Pollution'] = location_data.apply(lambda row: get_polution_aqi_data(row, apiKey), axis=1)
components_df = location_data.apply(lambda row: pd.Series(get_polution_components_data(row, apiKey)), axis=1)

location_data = location_data.join(components_df)

location_data.drop(columns='lat', axis=1, inplace=True)
location_data.drop(columns='lon', axis=1, inplace=True)
location_data['date'] = datetime.now().date()

location_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 24
#      22 location_data.drop(columns='date', axis=1, inplace=True)
#      23 location_data['date'] = datetime.now().date()
# ---> 24 location_data['date'].astype(datetime)
#      26 location_data
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/dtypes/astype.py:231, in astype_array_safe(values, dtype, copy, errors)
#     225     msg = (
#     226         f"Expected an instance of {dtype.__name__}, "
#     227         "but got the class instead. Try instantiating 'dtype'."
#     228     )
#     229     raise TypeError(msg)
# --> 231 dtype = pandas_dtype(dtype)
#     232 if isinstance(dtype, NumpyEADtype):
#     233     # Ensure we don't end up with a NumpyExtensionArray
#     234     dtype = dtype.numpy_dtype
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pandas/core/dtypes/common.py:1666, in pandas_dtype(dtype)
#    1664     return npdtype
#    1665 elif npdtype.kind == "O":
# -> 1666     raise TypeError(f"dtype '{dtype}' not understood")
#    1668 return npdtype
#
# TypeError: dtype '<class 'datetime.datetime'>' not understood
